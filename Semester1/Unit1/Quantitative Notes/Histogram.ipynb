# %%
import seaborn as sb
import pandas as pd

# %%
d = {0: .01, 1: .02, 3: .04, 4: .05, 5: .07, 6: .09, 7: .13, 8: .19, 9: .34, 10: .58, 11: .77, 12: .93}
data_series = pd.Series(data=d)

# %%
sb.histplot(
    data=data_series,
    binwidth=.2
)
# Out:
# <Axes: ylabel='Count'>
